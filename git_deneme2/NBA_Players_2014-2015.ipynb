# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("players_stats.csv")

# %%
df
# Out:
#               Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0         AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1     Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2     Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3    Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4       Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
# ..             ...           ...   ...   ...  ...  ...   ...  ...  ...   ...
# 485   Xavier Henry             9    86    20    3   13  23.1    0    0   0.0
# 486    Zach LaVine            77  1902   778  286  677  42.2   57  167  34.1
# 487  Zach Randolph            71  2304  1143  454  932  48.7    7   20  35.0
# 488  Zaza Pachulia            73  1730   606  240  529  45.4    0    3   0.0
# 489   Zoran Dragic            16    75    28   11   30  36.7    3   14  21.4
#
# ...

# %%
df.head(10)
# Out:
#             Name  Games Played   MIN   PTS  FGM   FGA   FG%  3PM  3PA   3P%  \
# 0       AJ Price            26   324   133   51   137  37.2   15   57  26.3
# 1   Aaron Brooks            82  1885   954  344   817  42.1  121  313  38.7
# 2   Aaron Gordon            47   797   243   93   208  44.7   13   48  27.1
# 3  Adreian Payne            32   740   213   91   220  41.4    1    9  11.1
# 4     Al Horford            76  2318  1156  519   965  53.8   11   36  30.6
# 5   Al Jefferson            65  1992  1082  486  1010  48.1    2    5  40.0
# 6  Alan Anderson            74  1744   545  195   440  44.3   73  210  34.8
# 7     Alec Burks            27   899   374  121   300  40.3   26   68  38.2
# 8      Alex Kirk             5    14     4    1     4  25.0    0    0   0.0
# 9       Alex Len            69  1518   432  179   353  50.7    1    3  33.3
#
#    ...   Age  Birth_Place           Birthdate                    Collage  \
# ...

# %%
df.tail()
# Out:
#               Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 485   Xavier Henry             9    86    20    3   13  23.1    0    0   0.0
# 486    Zach LaVine            77  1902   778  286  677  42.2   57  167  34.1
# 487  Zach Randolph            71  2304  1143  454  932  48.7    7   20  35.0
# 488  Zaza Pachulia            73  1730   606  240  529  45.4    0    3   0.0
# 489   Zoran Dragic            16    75    28   11   30  36.7    3   14  21.4
#
#      ...   Age  Birth_Place          Birthdate  \
# 485  ...  24.0           be     March 15, 1991
# 486  ...  20.0           us     March 10, 1995
# 487  ...  34.0           us      July 16, 1981
# 488  ...  31.0           ge  February 10, 1984
# 489  ...  26.0           si      June 22, 1989
#
#                                    Collage  Experience  Height  Pos  Team  \
# 485                   University of Kansas           4   195.0   SF   LAL
# ...

# %%
len(df.index)
# Out:
# 490

# %%
df
# Out:
#               Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0         AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1     Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2     Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3    Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4       Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
# ..             ...           ...   ...   ...  ...  ...   ...  ...  ...   ...
# 485   Xavier Henry             9    86    20    3   13  23.1    0    0   0.0
# 486    Zach LaVine            77  1902   778  286  677  42.2   57  167  34.1
# 487  Zach Randolph            71  2304  1143  454  932  48.7    7   20  35.0
# 488  Zaza Pachulia            73  1730   606  240  529  45.4    0    3   0.0
# 489   Zoran Dragic            16    75    28   11   30  36.7    3   14  21.4
#
# ...

# %%
df["Games Played"].mean()
# Out:
# 53.01428571428571

# %%
df["Games Played"].max()
# Out:
# 83

# %%
df[df["Games Played"]==df["Games Played"].max()]["Name"].iloc[0]
# Out:
# 'Josh Smith'

# %%
df[(df["Age"] > 25) & (df["Age"] < 30)][["Name","Team","Age"]].sort_values("Team")
# Out:
#                 Name Team   Age
# 4         Al Horford  ATL  29.0
# 339       Mike Scott  ATL  27.0
# 270    Kent Bazemore  ATL  26.0
# 110  DeMarre Carroll  ATL  29.0
# 215      Jeff Teague  ATL  27.0
# ..               ...  ...   ...
# 107     DeJuan Blair  WAS  26.0
# 277   Kevin Seraphin  WAS  26.0
# 385   Ramon Sessions  WAS  29.0
# 457     Toure' Murry  WAS  26.0
# 152   Garrett Temple  WAS  29.0
#
# [135 rows x 3 columns]

# %%
df[df["Name"] == "Alexey Shved"]["Team"].iloc[0]
# Out:
# 'NYK'

# %%
team = df.groupby("Team").mean()["3PM"]

# %%
team.sort_values(ascending = False)
# Out:
# Team
# GSW    61.066667
# BOS    60.250000
# HOU    56.909091
# POR    55.000000
# ATL    54.266667
# CLE    52.583333
# LAC    50.928571
# DAL    50.400000
# NYK    46.250000
# CHI    46.071429
# TOR    44.357143
# IND    44.000000
# OKC    43.800000
# DEN    43.272727
# DET    42.454545
# SAS    42.437500
# PHO    41.875000
# NOH    40.187500
# ORL    36.933333
# CHA    35.714286
# MIL    34.833333
# PHI    34.600000
# UTA    33.562500
# MEM    31.714286
# SAC    30.923077
# NJN    28.538462
# LAL    28.062500
# WAS    27.125000
# MIA    26.583333
# MIN    25.312500
# Name: 3PM, dtype: float64

# %%
team.count()
# Out:
# 30

# %%
len(df.groupby("Team"))
# Out:
# 30

# %%
df["Team"].nunique()
# Out:
# 30

# %%
df
# Out:
#               Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0         AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1     Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2     Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3    Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4       Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
# ..             ...           ...   ...   ...  ...  ...   ...  ...  ...   ...
# 485   Xavier Henry             9    86    20    3   13  23.1    0    0   0.0
# 486    Zach LaVine            77  1902   778  286  677  42.2   57  167  34.1
# 487  Zach Randolph            71  2304  1143  454  932  48.7    7   20  35.0
# 488  Zaza Pachulia            73  1730   606  240  529  45.4    0    3   0.0
# 489   Zoran Dragic            16    75    28   11   30  36.7    3   14  21.4
#
# ...

# %%
df["Team"].value_counts()
# Out:
# POR    16
# SAS    16
# LAL    16
# WAS    16
# NYK    16
# UTA    16
# NOH    16
# MIN    16
# PHO    16
# OKC    15
# PHI    15
# GSW    15
# DAL    15
# ATL    15
# ORL    15
# IND    15
# MEM    14
# CHI    14
# TOR    14
# LAC    14
# CHA    14
# NJN    13
# SAC    13
# MIA    12
# CLE    12
# MIL    12
# HOU    11
# DEN    11
# DET    11
# BOS     8
# Name: Team, dtype: int64

# %%
df[df["Name"].str.contains("and")]["Name"]
# Out:
# 48       Brandan Wright
# 49         Brandon Bass
# 50       Brandon Davies
# 51     Brandon Jennings
# 52       Brandon Knight
# 53         Brandon Rush
# 61          Carl Landry
# 66     Chandler Parsons
# 72       Chris Copeland
# 139         Elton Brand
# 236       Joel Freeland
# 259       Julius Randle
# 295       Landry Fields
# 298       Larry Sanders
# 300     Leandro Barbosa
# 386          Randy Foye
# 424    Shavlik Randolph
# 471      Tyson Chandler
# 473         Vander Blue
# 484     Wilson Chandler
# 487       Zach Randolph
# Name: Name, dtype: object

# %%
df
# Out:
#               Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0         AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1     Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2     Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3    Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4       Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
# ..             ...           ...   ...   ...  ...  ...   ...  ...  ...   ...
# 485   Xavier Henry             9    86    20    3   13  23.1    0    0   0.0
# 486    Zach LaVine            77  1902   778  286  677  42.2   57  167  34.1
# 487  Zach Randolph            71  2304  1143  454  932  48.7    7   20  35.0
# 488  Zaza Pachulia            73  1730   606  240  529  45.4    0    3   0.0
# 489   Zoran Dragic            16    75    28   11   30  36.7    3   14  21.4
#
# ...

# %%
df.drop(["Birth_Place","Collage"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          490 non-null    object
#  1   Games Played  490 non-null    int64
#  2   MIN           490 non-null    int64
#  3   PTS           490 non-null    int64
#  4   FGM           490 non-null    int64
#  5   FGA           490 non-null    int64
#  6   FG%           490 non-null    float64
#  7   3PM           490 non-null    int64
#  8   3PA           490 non-null    int64
#  9   3P%           490 non-null    float64
#  10  FTM           490 non-null    int64
#  11  FTA           490 non-null    int64
#  12  FT%           490 non-null    float64
#  13  OREB          490 non-null    int64
#  14  DREB          490 non-null    int64
#  15  REB           490 non-null    int64
#  16  AST           490 non-null    int64
#  17  STL           490 non-null    int64
# ...

# %%
df.drop(["FGM","FGA","FG%","FTM","FTA","3PM","3PA","TOV","PF","EFF","AST/TOV","STL/TOV","OREB","DREB"],axis=1,inplace=True)

# %%
df
# Out:
#               Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  BLK  \
# 0         AJ Price            26   324   133  26.3  66.7   32   46    7    0
# 1     Aaron Brooks            82  1885   954  38.7  83.3  166  261   54   15
# 2     Aaron Gordon            47   797   243  27.1  72.1  169   33   21   22
# 3    Adreian Payne            32   740   213  11.1  65.2  162   30   19    9
# 4       Al Horford            76  2318  1156  30.6  75.9  544  244   68   98
# ..             ...           ...   ...   ...   ...   ...  ...  ...  ...  ...
# 485   Xavier Henry             9    86    20   0.0  58.3    4    3    3    0
# 486    Zach LaVine            77  1902   778  34.1  84.2  214  276   54   10
# 487  Zach Randolph            71  2304  1143  35.0  76.5  747  153   69   14
# 488  Zaza Pachulia            73  1730   606   0.0  78.8  500  178   80   21
# 489   Zoran Dragic            16    75    28  21.4  60.0    8    5    2    0
#
# ...

# %%
df.fillna(value="?")
# Out:
#               Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  BLK  \
# 0         AJ Price            26   324   133  26.3  66.7   32   46    7    0
# 1     Aaron Brooks            82  1885   954  38.7  83.3  166  261   54   15
# 2     Aaron Gordon            47   797   243  27.1  72.1  169   33   21   22
# 3    Adreian Payne            32   740   213  11.1  65.2  162   30   19    9
# 4       Al Horford            76  2318  1156  30.6  75.9  544  244   68   98
# ..             ...           ...   ...   ...   ...   ...  ...  ...  ...  ...
# 485   Xavier Henry             9    86    20   0.0  58.3    4    3    3    0
# 486    Zach LaVine            77  1902   778  34.1  84.2  214  276   54   10
# 487  Zach Randolph            71  2304  1143  35.0  76.5  747  153   69   14
# 488  Zaza Pachulia            73  1730   606   0.0  78.8  500  178   80   21
# 489   Zoran Dragic            16    75    28  21.4  60.0    8    5    2    0
#
# ...

# %%
df["Experience"].str.contains("R")
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 485    False
# 486     True
# 487    False
# 488    False
# 489     True
# Name: Experience, Length: 490, dtype: object

# %%
df.drop("Birthdate",axis=1,inplace=True)

# %%
df
# Out:
#               Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  BLK  \
# 0         AJ Price            26   324   133  26.3  66.7   32   46    7    0
# 1     Aaron Brooks            82  1885   954  38.7  83.3  166  261   54   15
# 2     Aaron Gordon            47   797   243  27.1  72.1  169   33   21   22
# 3    Adreian Payne            32   740   213  11.1  65.2  162   30   19    9
# 4       Al Horford            76  2318  1156  30.6  75.9  544  244   68   98
# ..             ...           ...   ...   ...   ...   ...  ...  ...  ...  ...
# 485   Xavier Henry             9    86    20   0.0  58.3    4    3    3    0
# 486    Zach LaVine            77  1902   778  34.1  84.2  214  276   54   10
# 487  Zach Randolph            71  2304  1143  35.0  76.5  747  153   69   14
# 488  Zaza Pachulia            73  1730   606   0.0  78.8  500  178   80   21
# 489   Zoran Dragic            16    75    28  21.4  60.0    8    5    2    0
#
# ...

# %%
df.sort_values("Age")
# Out:
#                  Name  Games Played   MIN  PTS   3P%    FT%  REB  AST  STL  \
# 486       Zach LaVine            77  1902  778  34.1   84.2  214  276   54
# 2        Aaron Gordon            47   797  243  27.1   72.1  169   33   21
# 97         Dante Exum            82  1817  393  31.4   62.5  131  198   41
# 360       Noah Vonleh            25   259   83  38.5   69.2   86    4    4
# 57      Bruno Caboclo             8    23   10  66.7    0.0    2    0    0
# ..                ...           ...   ...  ...   ...    ...  ...  ...  ...
# 456       Tony Wroten            30   895  507  26.1   66.7   86  157   48
# 458       Travis Wear            51   672  199  36.7   76.9  106   40   15
# 462  Tristan Thompson            82  2194  693   0.0   64.1  657   39   34
# 468      Tyler Zeller            82  1731  833   0.0   82.3  465  113   18
# 470      Tyrus Thomas             2     7    4   0.0  100.0    0    1    0
#
#      BLK   Age Experience  Height  Pos Team  Weight        BMI
# ...

# %%
df.dropna(inplace=True)

# %%
df.sort_values("Age")
# Out:
#                Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  BLK  \
# 486     Zach LaVine            77  1902   778  34.1  84.2  214  276   54   10
# 2      Aaron Gordon            47   797   243  27.1  72.1  169   33   21   22
# 97       Dante Exum            82  1817   393  31.4  62.5  131  198   41   14
# 360     Noah Vonleh            25   259    83  38.5  69.2   86    4    4    9
# 57    Bruno Caboclo             8    23    10  66.7   0.0    2    0    0    1
# ..              ...           ...   ...   ...   ...   ...  ...  ...  ...  ...
# 476    Vince Carter            66  1091   384  29.7  78.9  133   79   43   14
# 367  Pablo Prigioni            67  1197   274  34.3  85.4  119  171   79    1
# 21     Andre Miller            81  1253   355  20.6  75.3  153  284   32    6
# 446      Tim Duncan            77  2227  1070  28.6  74.0  704  230   63  151
# 274   Kevin Garnett            47   952   323  14.3  80.0  311   77   46   17
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#               Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  BLK  \
# 0         AJ Price            26   324   133  26.3  66.7   32   46    7    0
# 1     Aaron Brooks            82  1885   954  38.7  83.3  166  261   54   15
# 2     Aaron Gordon            47   797   243  27.1  72.1  169   33   21   22
# 3    Adreian Payne            32   740   213  11.1  65.2  162   30   19    9
# 4       Al Horford            76  2318  1156  30.6  75.9  544  244   68   98
# ..             ...           ...   ...   ...   ...   ...  ...  ...  ...  ...
# 417   Xavier Henry             9    86    20   0.0  58.3    4    3    3    0
# 418    Zach LaVine            77  1902   778  34.1  84.2  214  276   54   10
# 419  Zach Randolph            71  2304  1143  35.0  76.5  747  153   69   14
# 420  Zaza Pachulia            73  1730   606   0.0  78.8  500  178   80   21
# 421   Zoran Dragic            16    75    28  21.4  60.0    8    5    2    0
#
# ...

# %%
df[df["3P%"]>=50]
# Out:
#                 Name  Games Played   MIN  PTS   3P%    FT%  REB  AST  STL  \
# 57     Bruno Caboclo             8    23   10  66.7    0.0    2    0    0
# 103   David Stockton             3    33    8  50.0   50.0    2    9    2
# 128    Dwight Buycks             6   123   52  63.6   90.0   12   14    3
# 129    Dwight Howard            41  1223  646  50.0   52.8  431   50   28
# 132      Earl Barron            16   143   32  50.0   50.0   28    5    4
# 190  Jamaal Franklin             3    13    3  50.0    0.0    2    3    0
# 219     Jerel McNeal             6    36    9  50.0  100.0    3    2    3
# 295    Landry Fields            26   216   46  50.0   83.3   26   15   11
# 302    Lester Hudson             5    56   18  50.0   75.0    8    5    6
# 309     Luke Babbitt            63   830  256  51.3   68.4  111   24   17
# 474    Victor Claver            10    76   24  54.5    0.0   20    1    1
#
#      BLK   Age Experience  Height Pos Team  Weight        BMI
# ...

# %%
df.sort_values("PTS",ascending=False,inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#                  Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  \
# 0        James Harden            81  2981  2217  37.5  86.8  459  565  154
# 1       Stephen Curry            80  2613  1900  44.3  91.4  341  619  163
# 2        LeBron James            69  2493  1743  35.4  71.0  416  511  109
# 3      Damian Lillard            82  2925  1720  34.3  86.4  378  507   97
# 4       Klay Thompson            77  2455  1668  43.9  87.9  247  222   87
# ..                ...           ...   ...   ...   ...   ...  ...  ...  ...
# 417       Sim Bhullar             3     3     2   0.0   0.0    1    1    0
# 418     Julius Randle             1    14     2   0.0   0.0    0    0    0
# 419       Kalin Lucas             1     6     0   0.0   0.0    0    0    1
# 420  Jerrelle Benimon             2     3     0   0.0   0.0    3    0    0
# 421        Seth Curry             2     8     0   0.0   0.0    2    1    0
#
#      BLK   Age Experience  Height Pos Team  Weight        BMI
# ...

# %%
df[df["PTS"]>=1000]
# Out:
#                       Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  \
# 194           James Harden            81  2981  2217  37.5  86.8  459  565
# 433          Stephen Curry            80  2613  1900  44.3  91.4  341  619
# 301           LeBron James            69  2493  1743  35.4  71.0  416  511
# 91          Damian Lillard            82  2925  1720  34.3  86.4  378  507
# 281          Klay Thompson            77  2455  1668  43.9  87.9  247  222
# ..                     ...           ...   ...   ...   ...   ...  ...  ...
# 35           Arron Afflalo            78  2502  1035  35.4  84.3  247  129
# 159  Giannis Antetokounmpo            81  2541  1030  15.9  74.1  542  207
# 191         Jamal Crawford            64  1703  1010  32.7  90.1  124  158
# 311              Luol Deng            72  2421  1007  35.5  76.1  376  139
# 315          Marcin Gortat            82  2453  1001   0.0  70.3  717   97
#
#      STL  BLK   Age Experience  Height Pos Team  Weight        BMI
# ...

# %%
df = df[df["PTS"].apply(lambda x:x>=1000)]

# %%
df
# Out:
#                       Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  \
# 194           James Harden            81  2981  2217  37.5  86.8  459  565
# 433          Stephen Curry            80  2613  1900  44.3  91.4  341  619
# 301           LeBron James            69  2493  1743  35.4  71.0  416  511
# 91          Damian Lillard            82  2925  1720  34.3  86.4  378  507
# 281          Klay Thompson            77  2455  1668  43.9  87.9  247  222
# ..                     ...           ...   ...   ...   ...   ...  ...  ...
# 35           Arron Afflalo            78  2502  1035  35.4  84.3  247  129
# 159  Giannis Antetokounmpo            81  2541  1030  15.9  74.1  542  207
# 191         Jamal Crawford            64  1703  1010  32.7  90.1  124  158
# 311              Luol Deng            72  2421  1007  35.5  76.1  376  139
# 315          Marcin Gortat            82  2453  1001   0.0  70.3  717   97
#
#      STL  BLK   Age Experience  Height Pos Team  Weight        BMI
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.reset_index(drop=True)
# Out:
#                         Name  Games Played   MIN   PTS   3P%   FT%   REB  AST  \
# 0               James Harden            81  2981  2217  37.5  86.8   459  565
# 1              Stephen Curry            80  2613  1900  44.3  91.4   341  619
# 2               LeBron James            69  2493  1743  35.4  71.0   416  511
# 3             Damian Lillard            82  2925  1720  34.3  86.4   378  507
# 4              Klay Thompson            77  2455  1668  43.9  87.9   247  222
# 5          LaMarcus Aldridge            71  2512  1661  35.2  84.5   726  124
# 6              Anthony Davis            68  2455  1656   8.3  80.5   696  149
# 7               Kyrie Irving            75  2730  1628  41.5  86.3   237  389
# 8                 Chris Paul            82  2857  1564  39.8  90.0   376  838
# 9                Monta Ellis            80  2699  1513  28.5  75.2   190  329
# 10             Blake Griffin            67  2356  1469  40.0  72.8   508  354
# ...

# %%
df[df["Name"].str.contains("James")]
# Out:
#              Name  Games Played   MIN   PTS   3P%   FT%  REB  AST  STL  BLK  \
# 194  James Harden            81  2981  2217  37.5  86.8  459  565  154   60
# 301  LeBron James            69  2493  1743  35.4  71.0  416  511  109   49
#
#       Age Experience  Height Pos Team  Weight        BMI
# 194  26.0          5   192.5  SG  HOU    99.0  26.716141
# 301  31.0         11   200.0  SF  CLE   112.5  28.125000

# %%
df["Age"] = df["Age"].apply(np.str)
# Out:
# <ipython-input-284-ff0f4a146f0e>:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df["Age"] = df["Age"].apply(np.str)
# <ipython-input-284-ff0f4a146f0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].apply(np.str)

# %%
df["Age"] = df["Age"].apply(lambda x:x.split(".")[0])
# Out:
# <ipython-input-287-b6de1bc391c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].apply(lambda x:x.split(".")[0])

# %%
df
# Out:
#                          Name  Games Played   MIN   PTS   3P%   FT%   REB  \
# 194              James Harden            81  2981  2217  37.5  86.8   459
# 433             Stephen Curry            80  2613  1900  44.3  91.4   341
# 301              LeBron James            69  2493  1743  35.4  71.0   416
# 91             Damian Lillard            82  2925  1720  34.3  86.4   378
# 281             Klay Thompson            77  2455  1668  43.9  87.9   247
# 292         LaMarcus Aldridge            71  2512  1661  35.2  84.5   726
# 29              Anthony Davis            68  2455  1656   8.3  80.5   696
# 291              Kyrie Irving            75  2730  1628  41.5  86.3   237
# 76                 Chris Paul            82  2857  1564  39.8  90.0   376
# 345               Monta Ellis            80  2699  1513  28.5  75.2   190
# 44              Blake Griffin            67  2356  1469  40.0  72.8   508
# 165            Gordon Hayward            76  2618  1463  36.4  81.2   373
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 194 to 315
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          61 non-null     object
#  1   Games Played  61 non-null     int64
#  2   MIN           61 non-null     int64
#  3   PTS           61 non-null     int64
#  4   3P%           61 non-null     float64
#  5   FT%           61 non-null     float64
#  6   REB           61 non-null     int64
#  7   AST           61 non-null     int64
#  8   STL           61 non-null     int64
#  9   BLK           61 non-null     int64
#  10  Age           61 non-null     object
#  11  Experience    61 non-null     object
#  12  Height        61 non-null     float64
#  13  Pos           61 non-null     object
#  14  Team          61 non-null     object
#  15  Weight        61 non-null     float64
#  16  BMI           61 non-null     float64
# dtypes: float64(5), int64(7), object(5)
# ...
